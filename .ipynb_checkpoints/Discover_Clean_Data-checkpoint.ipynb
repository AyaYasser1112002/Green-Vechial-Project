# %%
import pandas as pd

# %%
all_alpha_08 = pd.read_csv('all_alpha_08.csv')
all_alpha_18 = pd.read_csv('all_alpha_18.csv')

# %%
all_alpha_08.head()
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3  ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4   ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
#
#    Underhood ID    Veh Class Air Pollution Score FE Calc Appr City MPG  \
# 0  8HNXT03.7PKR          SUV                   7          Drv       15
# 1  8HNXT03.7PKR          SUV                   6          Drv       15
# 2  8HNXT02.3DKR          SUV                   7          Drv       17
# 3  8HNXT02.3DKR          SUV                   6          Drv       17
# 4  8HNXV03.5HKR  midsize car                   7          Drv       16
#
#   Hwy MPG Cmb MPG  Unadj Cmb MPG Greenhouse Gas Score SmartWay
# ...

# %%
all_alpha_18.head()
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region       Stnd  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA     T3B125
# 1  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA         U2
# 2  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          FA     T3B125
# 3  ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA         U2
# 4  ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA  L3ULEV125
#
#              Stnd Description  Underhood ID  Veh Class  Air Pollution Score  \
# 0      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 1      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 2      Federal Tier 3 Bin 125  JHNXT03.5GV3  small SUV                    3
# 3      California LEV-II ULEV  JHNXT03.5GV3  small SUV                    3
# 4  California LEV-III ULEV125  JHNXV02.4WH3  small car                    3
#
# ...

# %%
all_alpha_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2404 entries, 0 to 2403
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 2404 non-null   object
#  1   Displ                 2404 non-null   float64
#  2   Cyl                   2205 non-null   object
#  3   Trans                 2205 non-null   object
#  4   Drive                 2311 non-null   object
#  5   Fuel                  2404 non-null   object
#  6   Sales Area            2404 non-null   object
#  7   Stnd                  2404 non-null   object
#  8   Underhood ID          2404 non-null   object
#  9   Veh Class             2404 non-null   object
#  10  Air Pollution Score   2404 non-null   object
#  11  FE Calc Appr          2205 non-null   object
#  12  City MPG              2205 non-null   object
#  13  Hwy MPG               2205 non-null   object
#  14  Cmb MPG               2205 non-null   object
# ...

# %%
all_alpha_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1611 entries, 0 to 1610
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 1611 non-null   object
#  1   Displ                 1609 non-null   float64
#  2   Cyl                   1609 non-null   float64
#  3   Trans                 1611 non-null   object
#  4   Drive                 1611 non-null   object
#  5   Fuel                  1611 non-null   object
#  6   Cert Region           1611 non-null   object
#  7   Stnd                  1611 non-null   object
#  8   Stnd Description      1611 non-null   object
#  9   Underhood ID          1611 non-null   object
#  10  Veh Class             1611 non-null   object
#  11  Air Pollution Score   1611 non-null   int64
#  12  City MPG              1611 non-null   object
#  13  Hwy MPG               1611 non-null   object
#  14  Cmb MPG               1611 non-null   object
# ...

# %%
all_alpha_08.duplicated().sum()
# Out:
# 25

# %%
all_alpha_18.duplicated().sum()
# Out:
# 0

# %%
all_alpha_08.drop_duplicates(inplace = True)

# %%
all_alpha_08.duplicated().sum()
# Out:
# 0

# %%
all_alpha_18.drop_duplicates(inplace = True)

# %%
all_alpha_08['SmartWay'].nunique()
# Out:
# 2

# %%
all_alpha_18['SmartWay'].nunique()
# Out:
# 3

# %%
all_alpha_08['Sales Area'].nunique()
# Out:
# 3

# %%
all_alpha_18['Cert Region'].nunique()
# Out:
# 2

# %%
all_alpha_08['Cyl'].nunique()
# Out:
# 8

# %%
all_alpha_18['Cyl'].nunique()
# Out:
# 7

# %%
all_alpha_08['Fuel'].unique()
# Out:
# array(['Gasoline', 'ethanol/gas', 'ethanol', 'diesel', 'CNG'],
#       dtype=object)

# %%
all_alpha_18['Fuel'].unique()
# Out:
# array(['Gasoline', 'Gasoline/Electricity', 'Diesel', 'Ethanol/Gas',
#        'Electricity'], dtype=object)

# %%
all_alpha_08.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area', 'Stnd',
#        'Underhood ID', 'Veh Class', 'Air Pollution Score', 'FE Calc Appr',
#        'City MPG', 'Hwy MPG', 'Cmb MPG', 'Unadj Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay'],
#       dtype='object')

# %%
all_alpha_08['Fuel'].value_counts()
# Out:
# Gasoline       2293
# ethanol/gas      72
# diesel           11
# CNG               2
# ethanol           1
# Name: Fuel, dtype: int64

# %%
all_alpha_08.drop(columns = ['Stnd' , 'Underhood ID' , 'FE Calc Appr' , 'Unadj Cmb MPG'] , inplace = True)

# %%
all_alpha_18.columns
# Out:
# Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Cert Region',
#        'Stnd', 'Stnd Description', 'Underhood ID', 'Veh Class',
#        'Air Pollution Score', 'City MPG', 'Hwy MPG', 'Cmb MPG',
#        'Greenhouse Gas Score', 'SmartWay', 'Comb CO2'],
#       dtype='object')

# %%
all_alpha_18.drop(columns = ['Stnd' , 'Stnd Description' ,'Underhood ID','Comb CO2'] , inplace = True)

# %%
all_alpha_08.rename(columns = {'Sales Area': 'Cert Region'} , inplace = True)

# %%
all_alpha_08.columns = all_alpha_08.columns.str.lower()

# %%
all_alpha_18.columns = all_alpha_18.columns.str.lower()

# %%
all_alpha_08.columns = all_alpha_08.columns.str.replace(' ','_')
all_alpha_18.columns = all_alpha_18.columns.str.replace(' ','_')

# %%
all_alpha_08.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
all_alpha_18.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region',
#        'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
all_alpha_08.columns == all_alpha_18.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True])

# %%
all_alpha_08 = all_alpha_08[all_alpha_08['cert_region'] == 'CA']

# %%
all_alpha_18 = all_alpha_18[all_alpha_18['cert_region'] == 'CA']

# %%
all_alpha_08.drop(columns = ['cert_region'] , inplace = True)
all_alpha_18.drop(columns = ['cert_region'] , inplace = True)

# %%
all_alpha_18.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'veh_class',
#        'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
all_alpha_08.dropna(inplace = True)

# %%
all_alpha_18.dropna(inplace = True)

# %%
all_alpha_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1006 entries, 0 to 2400
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 1006 non-null   object
#  1   displ                 1006 non-null   float64
#  2   cyl                   1006 non-null   object
#  3   trans                 1006 non-null   object
#  4   drive                 1006 non-null   object
#  5   fuel                  1006 non-null   object
#  6   veh_class             1006 non-null   object
#  7   air_pollution_score   1006 non-null   object
#  8   city_mpg              1006 non-null   object
#  9   hwy_mpg               1006 non-null   object
#  10  cmb_mpg               1006 non-null   object
#  11  greenhouse_gas_score  1006 non-null   object
#  12  smartway              1006 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 110.0+ KB

# %%
all_alpha_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 797 entries, 1 to 1609
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 797 non-null    object
#  1   displ                 797 non-null    float64
#  2   cyl                   797 non-null    float64
#  3   trans                 797 non-null    object
#  4   drive                 797 non-null    object
#  5   fuel                  797 non-null    object
#  6   veh_class             797 non-null    object
#  7   air_pollution_score   797 non-null    int64
#  8   city_mpg              797 non-null    object
#  9   hwy_mpg               797 non-null    object
#  10  cmb_mpg               797 non-null    object
#  11  greenhouse_gas_score  797 non-null    int64
#  12  smartway              797 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 87.2+ KB

# %%
all_alpha_08.duplicated().sum()
# Out:
# 20

# %%
all_alpha_18.duplicated().sum()
# Out:
# 3

# %%
all_alpha_08.drop_duplicates(inplace = True)
all_alpha_18.drop_duplicates(inplace = True)

# %%
all_alpha_08.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 0 to 2400
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 986 non-null    object
#  1   displ                 986 non-null    float64
#  2   cyl                   986 non-null    object
#  3   trans                 986 non-null    object
#  4   drive                 986 non-null    object
#  5   fuel                  986 non-null    object
#  6   veh_class             986 non-null    object
#  7   air_pollution_score   986 non-null    object
#  8   city_mpg              986 non-null    object
#  9   hwy_mpg               986 non-null    object
#  10  cmb_mpg               986 non-null    object
#  11  greenhouse_gas_score  986 non-null    object
#  12  smartway              986 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 107.8+ KB

# %%
all_alpha_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 794 entries, 1 to 1609
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   model                 794 non-null    object
#  1   displ                 794 non-null    float64
#  2   cyl                   794 non-null    float64
#  3   trans                 794 non-null    object
#  4   drive                 794 non-null    object
#  5   fuel                  794 non-null    object
#  6   veh_class             794 non-null    object
#  7   air_pollution_score   794 non-null    int64
#  8   city_mpg              794 non-null    object
#  9   hwy_mpg               794 non-null    object
#  10  cmb_mpg               794 non-null    object
#  11  greenhouse_gas_score  794 non-null    int64
#  12  smartway              794 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 86.8+ KB

# %%
all_alpha_08['cyl'].unique()
# Out:
# array(['(6 cyl)', '(4 cyl)', '(12 cyl)', '(8 cyl)', '(10 cyl)',
#        '(16 cyl)', '(5 cyl)', '(2 cyl)'], dtype=object)

# %%
all_alpha_08['cyl'] = all_alpha_08['cyl'].str.extract('(\d+)').astype(int)

# %%
all_alpha_18['cyl'] = all_alpha_18['cyl'].astype('int')

# %%
all_alpha_08.to_csv('lv_08.csv' , index = False)
all_alpha_08.to_csv('lv_18.csv', index = False)

# %%
all_alpha_08['air_pollution_score'].unique()
# Out:
# array(['7', '6', '9.5', '9', '6/4'], dtype=object)

# %%
all_alpha_08['air_pollution_score'].str.split('/' , expand = True)
# Out:
#       0     1
# 0     7  None
# 2     7  None
# 4     7  None
# 6     7  None
# 7     7  None
# ...  ..   ...
# 2394  7  None
# 2396  7  None
# 2398  7  None
# 2399  7  None
# 2400  7  None
#
# [986 rows x 2 columns]

# %%
all_alpha_08['fuel'].str.contains('/').sum()
# Out:
# 1

# %%
all_alpha_18['fuel'].str.contains('/').sum()
# Out:
# 38

# %%
all_alpha_08.loc[all_alpha_08['fuel'].str.contains('/')]
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
all_alpha_18.loc[all_alpha_18['fuel'].str.contains('/')]
# Out:
#                                   model  displ  cyl       trans drive  \
# 108                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 160                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 162                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 188                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 382                    CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 394              CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 396              CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 398              CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 428             CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 432             CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 436                CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 440                CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# ...

# %%
all_alpha_08.columns
# Out:
# Index(['model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'veh_class',
#        'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
#        'greenhouse_gas_score', 'smartway'],
#       dtype='object')

# %%
all_alpha_08.loc[all_alpha_08['smartway'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
cols = ['fuel','air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
       'greenhouse_gas_score']

df_mody = all_alpha_08.loc[all_alpha_08['fuel'].str.contains('/')]
df_mody
# Out:
#                    model  displ  cyl    trans drive         fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol/gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
df_mody['fuel'].str.split('/' , expand = True)
# Out:
#             0    1
# 1550  ethanol  gas

# %%
df_cpy1 = df_mody.copy()
df_cpy1['fuel'] = df_mody['fuel'].str.split('/' , expand = True)[0]
df_cpy2 = df_mody.copy()
df_cpy2['fuel'] = df_mody['fuel'].str.split('/' , expand = True)[1]

# %%
df_cpy2
# Out:
#                    model  displ  cyl    trans drive fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                 6/4    13/18   19/25   15/21                  7/6
#
#      smartway
# 1550       no

# %%
cols = ['fuel','air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
       'greenhouse_gas_score']

df_mody = all_alpha_08.loc[all_alpha_08['fuel'].str.contains('/')]
df_cpy1 = df_mody.copy()
df_cpy2 = df_mody.copy()

for col in cols :
    df_cpy1[col] = df_mody[col].str.split('/' , expand = True)[0]
    df_cpy2[col] = df_mody[col].str.split('/' , expand = True)[1]
    
    
df_cpy1
# Out:
#                    model  displ  cyl    trans drive     fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  ethanol  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                   6       13      19      15                    7
#
#      smartway
# 1550       no

# %%
df_cpy2
# Out:
#                    model  displ  cyl    trans drive fuel  veh_class  \
# 1550  MERCEDES-BENZ C300    3.0    6  Auto-L7   2WD  gas  small car
#
#      air_pollution_score city_mpg hwy_mpg cmb_mpg greenhouse_gas_score  \
# 1550                   4       18      25      21                    6
#
#      smartway
# 1550       no

# %%
all_alpha_08 = all_alpha_08.append([df_cpy1,df_cpy2] , ignore_index = True)
all_alpha_08.shape
# Out:
# C:\Users\Aya Yasser\AppData\Local\Temp\ipykernel_3456\1296115395.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_alpha_08 = all_alpha_08.append([df_cpy1,df_cpy2] , ignore_index = True)
# (988, 13)

# %%
all_alpha_08.drop(all_alpha_08.loc[all_alpha_08['fuel'].str.contains('/')].index , inplace = True)

# %%
all_alpha_08.shape
# Out:
# (987, 13)

# %%
cols = ['model','fuel','air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg',
       'greenhouse_gas_score']

for col in cols :
    test_df = all_alpha_08.loc[all_alpha_08[col].str.contains('/')]
    
test_df
# Out:
# Empty DataFrame
# Columns: [model, displ, cyl, trans, drive, fuel, veh_class, air_pollution_score, city_mpg, hwy_mpg, cmb_mpg, greenhouse_gas_score, smartway]
# Index: []

# %%
df_mody = all_alpha_18.loc[all_alpha_18['fuel'].str.contains('/')]

# %%
cols = ['fuel','city_mpg', 'hwy_mpg', 'cmb_mpg']

df_cpy1 = df_mody.copy()
df_cpy2 = df_mody.copy()

for col in cols :
    df_cpy1[col] = df_mody[col].str.split('/' , expand = True)[0]
    df_cpy2[col] = df_mody[col].str.split('/' , expand = True)[1]
    
df_cpy1
# Out:
#                                   model  displ  cyl       trans drive  \
# 108                            BMW 330e    2.0    4  SemiAuto-8   2WD
# 160                            BMW 530e    2.0    4  SemiAuto-8   2WD
# 162                            BMW 530e    2.0    4  SemiAuto-8   4WD
# 188                            BMW 740e    2.0    4  SemiAuto-8   4WD
# 382                    CHEVROLET Impala    3.6    6  SemiAuto-6   2WD
# 394              CHEVROLET Silverado 15    4.3    6      Auto-6   2WD
# 396              CHEVROLET Silverado 15    4.3    6      Auto-6   4WD
# 398              CHEVROLET Silverado 15    5.3    8      Auto-6   2WD
# 428             CHEVROLET Suburban 1500    5.3    8      Auto-6   2WD
# 432             CHEVROLET Suburban 1500    5.3    8      Auto-6   4WD
# 436                CHEVROLET Tahoe 1500    5.3    8      Auto-6   2WD
# 440                CHEVROLET Tahoe 1500    5.3    8      Auto-6   4WD
# ...

# %%
df_cpy2.shape
# Out:
# (38, 13)

# %%
rem_index = all_alpha_18[all_alpha_18['fuel'].str.contains('/')].index

# %%
all_alpha_18 = pd.concat([all_alpha_18 , df_cpy1 , df_cpy2])

# %%
all_alpha_18.shape
# Out:
# (870, 13)

# %%
all_alpha_18.drop(rem_index)
# Out:
#             model  displ  cyl       trans drive      fuel     veh_class  \
# 1       ACURA RDX    3.5    6  SemiAuto-6   2WD  Gasoline     small SUV
# 3       ACURA RDX    3.5    6  SemiAuto-6   4WD  Gasoline     small SUV
# 4       ACURA TLX    2.4    4       AMS-8   2WD  Gasoline     small car
# 6       ACURA TLX    3.5    6  SemiAuto-9   2WD  Gasoline     small car
# 8       ACURA TLX    3.5    6  SemiAuto-9   4WD  Gasoline     small car
# ...           ...    ...  ...         ...   ...       ...           ...
# 1597  VOLVO XC 60    2.0    4  SemiAuto-8   4WD  Gasoline     small SUV
# 1599  VOLVO XC 60    2.0    4  SemiAuto-8   4WD  Gasoline     small SUV
# 1603  VOLVO XC 90    2.0    4  SemiAuto-8   2WD  Gasoline  standard SUV
# 1605  VOLVO XC 90    2.0    4  SemiAuto-8   4WD  Gasoline  standard SUV
# 1607  VOLVO XC 90    2.0    4  SemiAuto-8   4WD  Gasoline  standard SUV
#
#       air_pollution_score city_mpg hwy_mpg cmb_mpg  greenhouse_gas_score  \
# ...
